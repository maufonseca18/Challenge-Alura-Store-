# %% [markdown]
# <a href="https://colab.research.google.com/github/maufonseca18/Challenge-Alura-Store-/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

df= pd.concat([tienda, tienda2, tienda3, tienda4], ignore_index=True)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# ##**Ingresos Todal por Tienda**

# %%
import pandas as pd
urls = {
    'Tienda 1': "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_1%20.csv",
    'Tienda 2': "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_2.csv",
    'Tienda 3': "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_3.csv",
    'Tienda 4': "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_4.csv"
}
ingresos = {}
for nombre, url in urls.items():
    df = pd.read_csv(url)
    ingresos[nombre] = df['Precio'].sum()


print("Ingresos totales por tienda:")
for tienda, total in ingresos.items():
    print(f"- {tienda}: ${total:,.2f}")  # Formato con separadores de miles
# Out:
# Ingresos totales por tienda:
# - Tienda 1: $1,150,880,400.00
# - Tienda 2: $1,116,343,500.00
# - Tienda 3: $1,098,019,600.00
# - Tienda 4: $1,038,375,700.00

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
bars= plt.bar(ingresos.keys(),ingresos.values(),color= 'Red')
plt.title('Ingresos totales por tienda', fontweight= 'bold')
plt.xlabel('Tiendas', fontsize=12)
plt.ylabel('Ingresos totales', fontsize=12)
plt.grid(axis= 'y', linestyle= '--', alpha= 0.7)

for bar in bars:
  heigth = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2., heigth,
           f'${heigth:,.2f}', ha='center', va='bottom', fontsize=10)

plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-pastel')
plt.rcParams['font.size'] = 12
urls = {
    'Tienda 1': "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_1%20.csv",
    'Tienda 2': "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_2.csv",
    'Tienda 3': "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_3.csv",
    'Tienda 4': "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_4.csv"
}

tiendas = {nombre: pd.read_csv(url) for nombre, url in urls.items()}

for nombre, df in tiendas.items():
    ventas_por_categoria = df['Categoría del Producto'].value_counts().reset_index()
    ventas_por_categoria.columns = ['Categoría', 'Ventas Totales']

    ventas_por_categoria = ventas_por_categoria.sort_values('Ventas Totales', ascending=False)

    print(f"\n **{nombre}**")
    print(ventas_por_categoria.to_string(index=False))

    top_5 = ventas_por_categoria.head(5)
    plt.figure(figsize=(10, 5))
    bars = plt.barh(
              top_5['Categoría'],
              top_5['Ventas Totales'],
              color=['Blue', 'Orange', 'Yellow', 'Red', 'Purple']
            )
    for bar in bars:
        width = bar.get_width()
        plt.text(width + 1, bar.get_y() + bar.get_height()/2,
                f'{int(width)}',
                va='center', ha='left', fontsize=10)

    plt.title(f'Top 5 Categorías Más Vendidas - {nombre}', pad=20, fontweight='bold')
    plt.xlabel('Cantidad de Ventas')
    plt.gca().invert_yaxis()
    plt.tight_layout()
    plt.show()
# Out:
#  **Tienda 1**
#               Categoría  Ventas Totales
#                 Muebles             465
#            Electrónicos             448
#                Juguetes             324
#       Electrodomésticos             312
#    Deportes y diversión             284
#  Instrumentos musicales             182
#                  Libros             173
# Artículos para el hogar             171
#  **Tienda 2**
#               Categoría  Ventas Totales
#                 Muebles             442
#            Electrónicos             422
#                Juguetes             313
#       Electrodomésticos             305
#    Deportes y diversión             275
#  Instrumentos musicales             224
#                  Libros             197
# Artículos para el hogar             181
#  **Tienda 3**
#               Categoría  Ventas Totales
#                 Muebles             499
#            Electrónicos             451
#                Juguetes             315
#       Electrodomésticos             278
#    Deportes y diversión             277
#                  Libros             185
#  Instrumentos musicales             177
# Artículos para el hogar             177
#  **Tienda 4**
#               Categoría  Ventas Totales
#                 Muebles             480
#            Electrónicos             451
#                Juguetes             338
#    Deportes y diversión             277
#       Electrodomésticos             254
# Artículos para el hogar             201
#                  Libros             187
#  Instrumentos musicales             170

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['font.size'] = 12

#Cálculo promedio de las calificaciones por tienda:
calificacion = {}
for nombre, df in tiendas.items():
  promedio = df['Calificación'].mean()
  calificacion[nombre] = round(promedio, 2) #Lo va a redondear dos decímales

print("Calificaciones Promedio por Tienda (1-5):")
for tienda, promedio in calificacion.items():
    print(f"- {tienda}: {promedio}/5")
plt.figure(figsize=(10, 6))
bars = plt.bar(
    calificacion.keys(),
    calificacion.values(),
    color= ['Blue', 'Orange', 'Yellow', 'Red']
    )
for bar in bars:
    height = bar.get_height()
    plt.text(
              bar.get_x() + bar.get_width() / 2, height,
              f'{height:.2f}',
              ha='center', va='bottom', fontsize=12
            )
plt.title('Satisfacción del Cliente por Tienda', pad=20, fontweight='bold')
plt.ylabel('Calificación Promedio (1-5)')
plt.ylim(0, 5.5)  # Rango de calificaciones
plt.tight_layout()
plt.show()
# Out:
# Calificaciones Promedio por Tienda (1-5):
# - Tienda 1: 3.98/5
# - Tienda 2: 4.04/5
# - Tienda 3: 4.05/5
# - Tienda 4: 4.0/5

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-notebook')
plt.rcParams['font.size'] = 12
plt.rcParams['axes.titlepad'] = 20

#filtros por categorías falsas
def filtrar_productos_fisicos(df):
    palabras_digitales = [
        "Ciencia de datos", "programación", "Power BI", "Dashboard",
        "Python", "Iniciando en", "curso", "taller", "datos con"
    ]
    mask = ~df['Producto'].str.contains('|'.join(palabras_digitales),
                                        case=False, regex=True)
    return df[mask]

resultados = {}
for nombre, df in tiendas.items():
  df_fisicos = filtrar_productos_fisicos(df)
  ventas_producto = df_fisicos['Producto'].value_counts().reset_index()
  ventas_producto.columns = ['Producto', 'Ventas']

# calc con un top 5 de los produtos más vendidos por tiendas
  top_5_mas_vendidos = ventas_producto.head(5)
  top_5_menos_vendidos = ventas_producto[ventas_producto['Ventas'] > 0].tail(5)
  print(f"\n**{nombre}**")
  print("Top 5 Productos Más Vendidos:")
  print(top_5_mas_vendidos.to_string(index=False))
  resultados[nombre] = {
      'top_5_mas_vendidos': top_5_mas_vendidos,
      'top_5_menos_vendidos': top_5_menos_vendidos
  }

  fig, (ax1,ax2) = plt.subplots(1,2, figsize=(16,6))
  fig.suptitle(f'Análisis de Ventas - {nombre}', fontweight='bold', y=1.05)

# productos más vendidos
  top_5_mas_vendidos.plot.barh(x='Producto', y='Ventas', ax=ax1, color='Green',edgecolor = 'Black', title='Top 5 Productos Más Vendidos')
  ax1.set_title('Top 5 Productos más vendidos por tienda', pad=15)
  ax1.set_xlabel('Cantidad de Ventas')
  ax1.invert_yaxis() # mayor-menor

# productos menos vendidos
  top_5_menos_vendidos.plot.barh(x='Producto', y='Ventas', ax=ax2, color= 'Red',edgecolor= 'Black', title='Top 5 Productos Menos Vendidos')
  ax2.set_title('Top 5 Productos Menos Vendidos por tienda', pad=15)
  ax2.set_xlabel('Cantidad de Ventas')
  ax2.invert_yaxis()

  for ax in (ax1, ax2):
    for p in ax.patches:
      width = p.get_width()
      ax.annotate(f'{int(width)}',
                  (width * 0.95, p.get_y() + p.get_height()/2),
                  ha='right', va= 'center', color= 'white', fontweight='bold')


  plt.tight_layout()
  plt.show()


print("\n Resumen de datos:")
for tienda, datos in resultados.items():
  print(f"\n{tienda}:")
  print("Top 5:", ','.join(datos['top_5_mas_vendidos']['Producto'].tolist()))
  print("Bottom 5:", ','.join(datos['top_5_menos_vendidos']['Producto'].tolist()))
# Out:
# **Tienda 1**
# Top 5 Productos Más Vendidos:
#         Producto  Ventas
#       Microondas      60
#    TV LED UHD 4K      60
#          Armario      60
# Secadora de ropa      58
#    Mesa de noche      56
# **Tienda 2**
# Top 5 Productos Más Vendidos:
#          Producto  Ventas
#        Microondas      62
#           Batería      61
#         Pandereta      58
# Guitarra acústica      58
#  Secadora de ropa      57
# **Tienda 3**
# Top 5 Productos Más Vendidos:
#        Producto  Ventas
#   Kit de bancas      57
# Mesa de comedor      56
#       Cama king      56
#   Mesa de noche      55
#    Set de ollas      55
# **Tienda 4**
# Top 5 Productos Más Vendidos:
#        Producto  Ventas
#        Cama box      62
#      Cubertería      59
#       Cama king      56
#   Mesa de noche      55
# Mesa de comedor      55
#  Resumen de datos:
#
# Tienda 1:
# Top 5: Microondas,TV LED UHD 4K,Armario,Secadora de ropa,Mesa de noche
# Bottom 5: Mochila,Pandereta,Olla de presión,Auriculares con micrófono,Celular ABXY
#
# Tienda 2:
# Top 5: Microondas,Batería,Pandereta,Guitarra acústica,Secadora de ropa
# Bottom 5: Auriculares,Sillón,Mesa de comedor,Impresora,Juego de mesa
#
# Tienda 3:
# Top 5: Kit de bancas,Mesa de comedor,Cama king,Mesa de noche,Set de ollas
# Bottom 5: Guitarra eléctrica,Set de vasos,Mochila,Microondas,Bloques de construcción
#
# Tienda 4:
# Top 5: Cama box,Cubertería,Cama king,Mesa de noche,Mesa de comedor
# Bottom 5: Refrigerador,Lavadora de ropa,Guitarra acústica,Armario,Guitarra eléctrica

# %% [markdown]
# # 5. Envío promedio por tienda
