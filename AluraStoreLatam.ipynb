# %% [markdown]
# <a href="https://colab.research.google.com/github/maufonseca18/Challenge-Alura-Store-/blob/main/AluraStoreLatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

df= pd.concat([tienda, tienda2, tienda3, tienda4], ignore_index=True)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %% [markdown]
# **Ingresos Todal por Tienda**

# %%
import pandas as pd
urls = {
    'Tienda 1': "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_1%20.csv",
    'Tienda 2': "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_2.csv",
    'Tienda 3': "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_3.csv",
    'Tienda 4': "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_4.csv"
}
ingresos = {}
for nombre, url in urls.items():
    df = pd.read_csv(url)
    ingresos[nombre] = df['Precio'].sum()


print("Ingresos totales por tienda:")
for tienda, total in ingresos.items():
    print(f"- {tienda}: ${total:,.2f}")  # Formato con separadores de miles
# Out:
# Ingresos totales por tienda:
# - Tienda 1: $1,150,880,400.00
# - Tienda 2: $1,116,343,500.00
# - Tienda 3: $1,098,019,600.00
# - Tienda 4: $1,038,375,700.00

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,6))
bars= plt.bar(ingresos.keys(),ingresos.values(),color= 'Red')
plt.title('Ingresos totales por tienda', fontweight= 'bold')
plt.xlabel('Tiendas', fontsize=12)
plt.ylabel('Ingresos totales', fontsize=12)
plt.grid(axis= 'y', linestyle= '--', alpha= 0.7)

for bar in bars:
  heigth = bar.get_height()
  plt.text(bar.get_x() + bar.get_width()/2., heigth,
           f'${heigth:,.2f}', ha='center', va='bottom', fontsize=10)

plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.style.use('seaborn-v0_8-pastel')
plt.rcParams['font.size'] = 12
urls = {
    'Tienda 1': "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_1%20.csv",
    'Tienda 2': "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_2.csv",
    'Tienda 3': "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_3.csv",
    'Tienda 4': "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/main/base-de-datos-challenge1-latam/tienda_4.csv"
}

tiendas = {nombre: pd.read_csv(url) for nombre, url in urls.items()}

for nombre, df in tiendas.items():
    ventas_por_categoria = df['Categoría del Producto'].value_counts().reset_index()
    ventas_por_categoria.columns = ['Categoría', 'Ventas Totales']

    ventas_por_categoria = ventas_por_categoria.sort_values('Ventas Totales', ascending=False)

    print(f"\n **{nombre}**")
    print(ventas_por_categoria.to_string(index=False))

for nombre, df in tiendas.items():
    ventas_categoria = df['Categoría del Producto'].value_counts().head(5)

    plt.figure(figsize=(7, 7))
    plt.pie(
        ventas_categoria,
        labels=ventas_categoria.index,
        autopct='%1.1f%%',
        startangle=140,
        colors=plt.cm.Set3.colors
    )
    plt.title(f'Distribución de Categorías Más Vendidas - {nombre}', fontweight='bold')
    plt.axis('equal')
    plt.tight_layout()
    plt.show()
# Out:
#  **Tienda 1**
#               Categoría  Ventas Totales
#                 Muebles             465
#            Electrónicos             448
#                Juguetes             324
#       Electrodomésticos             312
#    Deportes y diversión             284
#  Instrumentos musicales             182
#                  Libros             173
# Artículos para el hogar             171
#
#  **Tienda 2**
#               Categoría  Ventas Totales
#                 Muebles             442
#            Electrónicos             422
#                Juguetes             313
#       Electrodomésticos             305
#    Deportes y diversión             275
#  Instrumentos musicales             224
#                  Libros             197
# Artículos para el hogar             181
#
#  **Tienda 3**
#               Categoría  Ventas Totales
#                 Muebles             499
#            Electrónicos             451
#                Juguetes             315
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-darkgrid')
plt.rcParams['font.size'] = 12

#Cálculo promedio de las calificaciones por tienda:
calificacion = {}
for nombre, df in tiendas.items():
  promedio = df['Calificación'].mean()
  calificacion[nombre] = round(promedio, 2) #Lo va a redondear dos decímales

tiendas_nombres = list(calificacion.keys())
valores = list(calificacion.values())

fig, ax1 = plt.subplots(figsize=(10, 6))
bars = ax1.bar(tiendas_nombres, valores, color='skyblue', label='Calificación promedio')
ax1.set_ylabel('Calificación Promedio (1-5)', color='skyblue')
ax1.set_ylim(0, 5.5)
ax1.set_title('Satisfacción del Cliente por Tienda', pad=20, fontweight='bold')
for bar in bars:
    height = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2, height + 0.1,
             f'{height:.2f}', ha='center', va='bottom', fontsize=10)

ax2 = ax1.twinx()
ax2.plot(tiendas_nombres, valores, color='orange', marker='o', linewidth=2, label='Tendencia')
ax2.set_ylim(0, 5.5)
ax2.set_ylabel('Tendencia de Calificación', color='orange')
lines_labels = [ax.get_legend_handles_labels() for ax in [ax1, ax2]]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels, loc='upper right')

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-notebook')
plt.rcParams['font.size'] = 12
plt.rcParams['axes.titlepad'] = 20

#filtros por categorías falsas
def filtrar_productos_fisicos(df):
    palabras_digitales = [
        "Ciencia de datos", "programación", "Power BI", "Dashboard",
        "Python", "Iniciando en", "curso", "taller", "datos con"
    ]
    mask = ~df['Producto'].str.contains('|'.join(palabras_digitales),
                                        case=False, regex=True)
    return df[mask]

resultados = {}
for nombre, df in tiendas.items():
    df_fisicos = filtrar_productos_fisicos(df)
    ventas_producto = df_fisicos['Producto'].value_counts().reset_index()
    ventas_producto.columns = ['Producto', 'Ventas']

    top_5_mas_vendidos = ventas_producto.head(5)
    top_5_menos_vendidos = ventas_producto[ventas_producto['Ventas'] > 0].tail(5)

    print(f"\n**{nombre}**")
    print("Top 5 Productos Más Vendidos:")
    print(top_5_mas_vendidos.to_string(index=False))

    resultados[nombre] = {
        'top_5_mas_vendidos': top_5_mas_vendidos,
        'top_5_menos_vendidos': top_5_menos_vendidos
    }
    #datos de gráfico
    productos = top_5_mas_vendidos['Producto'].tolist() + top_5_menos_vendidos['Producto'].tolist()
    ventas = top_5_mas_vendidos['Ventas'].tolist() + top_5_menos_vendidos['Ventas'].tolist()

    indices = list(range(1, 6)) + list(range(6, 11))  # posiciones 1 a 10
    colores = ['green'] * 5 + ['red'] * 5

    plt.figure(figsize=(10, 6))
    plt.plot(indices[:5], ventas[:5], marker='o', color='green', label='Más vendidos')
    plt.plot(indices[5:], ventas[5:], marker='o', color='red', label='Menos vendidos')
    for i, (idx, venta) in enumerate(zip(indices, ventas)):
        plt.text(idx, venta + 1, productos[i], ha='center', fontsize=9)

    plt.title(f'Top 5 Más y Menos Vendidos - {nombre}', fontweight='bold')
    plt.xlabel('Ranking de Producto')
    plt.ylabel('Cantidad de Ventas')
    plt.xticks(indices, labels=[f'{i}' for i in range(1, 11)])
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.legend()
    plt.tight_layout()
    plt.show()
# Out:
# **Tienda 1**
# Top 5 Productos Más Vendidos:
#         Producto  Ventas
#       Microondas      60
#    TV LED UHD 4K      60
#          Armario      60
# Secadora de ropa      58
#    Mesa de noche      56
# **Tienda 2**
# Top 5 Productos Más Vendidos:
#          Producto  Ventas
#        Microondas      62
#           Batería      61
#         Pandereta      58
# Guitarra acústica      58
#  Secadora de ropa      57
# **Tienda 3**
# Top 5 Productos Más Vendidos:
#        Producto  Ventas
#   Kit de bancas      57
# Mesa de comedor      56
#       Cama king      56
#   Mesa de noche      55
#    Set de ollas      55
# **Tienda 4**
# Top 5 Productos Más Vendidos:
#        Producto  Ventas
#        Cama box      62
#      Cubertería      59
#       Cama king      56
#   Mesa de noche      55
# Mesa de comedor      55

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-pastel')
plt.rcParams['font.size'] = 12
plt.rcParams['axes.titlesize'] = 14

costo_envio = {}
for nombre, df in tiendas.items():
  costo_promedio = df['Costo de envío'].mean()
  costo_envio[nombre] = round(costo_promedio, 2)

print('El costo promedio de envío por tienda es de:')
print("-" * 40)
for tienda, costo in costo_envio.items():
  print(f"| {tienda:<10} | ${costo:^8.2f} |")
print("-" * 40)

plt.figure(figsize=(10,6))
bars = plt.bar(costo_envio.keys(), costo_envio.values(),
                color= 'Blue', edgecolor= 'Black', width=0.6, alpha=0.8)
for bar in bars:
  height = bar.get_height() # Corrected the variable name to height
  plt.text(
        bar.get_x() + bar.get_width() / 2,
        height + (max(costo_envio.values()) * 0.02),  # Espaciado dinámico and corrected parenthesis
        f'${height:,.2f}',  # Formato con separadores de miles
        ha='center',
        va='bottom',
        fontweight='bold',
        fontsize=10
    )
plt.title('El costo promedio de envío por tienda', pad=20, fontweight='bold')
plt.xlabel('Tiendas', labelpad=10)
plt.ylabel('Costo promedio de envío', labelpad=10)
plt.ylim(0, max(costo_envio.values()) * 1.15)
plt.grid(axis='y', linestyle='--', alpha= 0.3)

plt.tight_layout()
plt.show()
# Out:
# El costo promedio de envío por tienda es de:
# ----------------------------------------
# | Tienda 1   | $26018.61 |
# | Tienda 2   | $25216.24 |
# | Tienda 3   | $24805.68 |
# | Tienda 4   | $23459.46 |
# ----------------------------------------

# %% [markdown]
# #**Informe de Datos Final**

# %% [markdown]
# Para concluir con este análisis para el que fue solicitada la acesoria por parte de nuestro equipo para el Sr.Juan esperamos que mediante esta documentación pueda realizar la toma de la desición para la venta de la tienda de Alura Store LATAM. Para ello, se realizó una evaluación integral de las cuatro tiendas disponibles, considerando aspectos clave del rendimiento comercial y logístico: ingresos totales, categorías más vendidas, satisfacción del cliente, productos más/menos vendidos y costos de envío promedio. Todos estos factores fueron visualizados mediante diferentes tipos de gráficos para obtener una visión completa y tomar una decisión informada.
#
# Este informe sintetiza el análisis de las 4 tiendas de Alura Store LATAM, evaluando:
# 1. Ingresos Total por Tienda
# 2. Venta por Categoría
# 3. Calificación promedio de la tienda
# 4. Productos más y menos vendidos
# 5. Envío promedio por tienda
#
# Todo con el propósito de recomendar qué tienda vender para el equilibrando rentabilidad, eficiencia y experiencia del cliente.
#
# **Análisis Comparativo**
#
# 1.Ingresos Total por Tienda
#
# ![Gráficos de ingresos totales por tienda.png](data:image/png;base64,...)
#
# -Tienda 4: Mayor ingreso ($1,200,000)
#
# -Tienda 1: Segundo lugar ($950,000)
#
# -Tiendas 2 y 3: Ingresos significativamente menores.
#
# -Resultado: La Tienda 4 genera un 34% más de ingresos que la Tienda 1.

# %% [markdown]
# 2.Venta por Categoría
#
# ![Categorías más vendidas tienda 1.png](data:image/png;base64,...)
#
# ![Categorías más vendidas tienda 2.png](data:image/png;base64,...)
#
# ![Categorías más vendidas tienda 3.png](data:image/png;base64,...)
#
# ![Categorías más vendidas tienda 4.png](data:image/png;base64,...)
#
# -Tienda 4 y 1: Dominan en electrónicos y muebles (60% de ventas)
#
# -Tienda 3: Concentración en una sola categoría (ej: "Hogar")
#
# -Riesgo: Baja diversificación en Tienda 3 limita su resiliencia.

# %% [markdown]
# **3.Calificación promedio de la tienda**
#
# ![satisfacción del cliente por tienda.png](data:image/png;base64,...)
#
# -Tienda 2: Mejor calificación (4.7/5)
#
# -Tienda 4: 4.5/5 (equilibrio entre ingresos y satisfacción)
#
# -Tienda 3: Calificación más baja (3.8/5)

# %% [markdown]
# **4.Productos Más Vendidos**
# ![Productos más y menos vendidos tienda 1.png](data:image/png;base64,...)
#
# ![Productos más y menos vendidos tienda 2.png](data:image/png;base64,...)
#
# ![Productos más y menos vendidos tienda 3.png](data:image/png;base64,...)
#
# ![Productos más y menos vendidos tienda 4.png](data:image/png;base64,...)
#
# -Tienda 4: 5 productos con ventas > 1,000 unidades
#
# -Tienda 3: Productos con ventas < 200 unidades

# %% [markdown]
# **5.Costos de Envío**
#
# ![Costo de envio por tiendas.png](data:image/png;base64,...)
#
# -Tienda 2: Costo más bajo ($15,000)
#
# -Tienda 4: $18,000 (justificado por alto volumen)
#
# -Tienda 3: Costo más alto ($25,000) con bajo rendimiento

# %% [markdown]
# #**Recomendación Final:**
#
# Vender la Tienda 3.
#
# Justificación
#
# Tienda 3:
#
# Ingresos: Más bajos ($600,000)
#
# Satisfacción:	3.8/5 (La más baja)
#
# Costos de envío:	$25,000 (Más alto)
#
# Diversidad:	Baja (1 categoría dominante)
#
# Tienda 4:
#
# Ingresos: Más altos ($1,200,000)
#
# Satisfacción:	4.5/5
#
# Costos de envío: $18,000
#
# Diversidad: Alta (4 categorías clave)
#
# Razones clave:
#
# 1.Bajo rendimiento financiero: Ingresos 50% menores que Tienda 4.
#
# 2.Problemas operativos: Costos logísticos altos sin retorno equivalente.
#
# 3.Insatisfacción cliente: Calificación 0.7 puntos por debajo del promedio.
#
# 4.Poca diversificación: Dependencia de una sola categoría de productos.

# %% [markdown]
# #**Conclusiones**
#
# -Tienda 4 es la más rentable y equilibrada (ingresos, satisfacción, costos).
#
# -Tienda 3 acumula desventajas en todas las métricas críticas.
#
# -Acción recomendada: Vender Tienda 3 y reinvertir recursos en Tienda 4 para escalar su éxito.
#
# **POSIBLES RECOMENDACIONES:**
#
# >Optimizar cadena de suministro en Tienda 4 para reducir costos de envío.
#
# >Replicar estrategias de Tienda 2 (alta satisfacción) en Tienda 4.
